# %%
from keras.applications import inception_v3

# %%
model = inception_v3.InceptionV3(weights='imagenet')

# %%
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %%
image = io.imread('./cat.jpg')
plt.imshow(image)

# %%
from keras import preprocessing

# %%
img = preprocessing.image.load_img('./cat.jpg', target_size=(299,299))
x = preprocessing.image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x = inception_v3.preprocess_input(x)
predictions = model.predict(x)
labels = inception_v3.decode_predictions(predictions, top=3)[0]

labels
# Out:
# [('n02124075', 'Egyptian_cat', 0.15214784),
#  ('n02123045', 'tabby', 0.11405952),
#  ('n02123159', 'tiger_cat', 0.08813072)]
